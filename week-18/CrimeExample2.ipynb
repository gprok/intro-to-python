# %%
# pip install pandas (to install pandas library)
import pandas as pd

# %%
data = pd.read_csv('crimes.csv')

# %%
# Get number of rows and columns
data.shape
# Out:
# (104178, 22)

# %%
data.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  12943607    JG106063  01/06/2023 02:22:00 AM  002XX S LAVERGNE AVE  0313
# 1  12943730    JG106158  01/06/2023 12:00:00 AM    018XX N WILMOT AVE  1320
# 2  12944080    JG106206  01/06/2023 08:25:00 AM     050XX W QUINCY ST  1310
# 3  12944580    JG107088  01/06/2023 08:17:00 PM  047XX W VAN BUREN ST  0470
# 4  12944435    JG107020  01/06/2023 07:20:00 PM  003XX N MICHIGAN AVE  0460
#
#              Primary Type                     Description  \
# 0                 ROBBERY  ARMED - OTHER DANGEROUS WEAPON
# 1         CRIMINAL DAMAGE                      TO VEHICLE
# 2         CRIMINAL DAMAGE                     TO PROPERTY
# 3  PUBLIC PEACE VIOLATION                RECKLESS CONDUCT
# 4                 BATTERY                          SIMPLE
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104178 entries, 0 to 104177
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    104178 non-null  int64
#  1   Case Number           104178 non-null  object
#  2   Date                  104178 non-null  object
#  3   Block                 104178 non-null  object
#  4   IUCR                  104178 non-null  object
#  5   Primary Type          104178 non-null  object
#  6   Description           104178 non-null  object
#  7   Location Description  103728 non-null  object
#  8   Arrest                104178 non-null  bool
#  9   Domestic              104178 non-null  bool
#  10  Beat                  104178 non-null  int64
#  11  District              104178 non-null  int64
#  12  Ward                  104177 non-null  float64
#  13  Community Area        104178 non-null  int64
# ...

# %%
data['Primary Type'].unique()
# Out:
# array(['ROBBERY', 'CRIMINAL DAMAGE', 'PUBLIC PEACE VIOLATION', 'BATTERY',
#        'MOTOR VEHICLE THEFT', 'THEFT', 'NARCOTICS', 'DECEPTIVE PRACTICE',
#        'OTHER OFFENSE', 'ASSAULT', 'HOMICIDE', 'BURGLARY',
#        'CRIMINAL TRESPASS', 'WEAPONS VIOLATION',
#        'CONCEALED CARRY LICENSE VIOLATION', 'CRIMINAL SEXUAL ASSAULT',
#        'OFFENSE INVOLVING CHILDREN', 'SEX OFFENSE', 'ARSON', 'KIDNAPPING',
#        'INTERFERENCE WITH PUBLIC OFFICER', 'INTIMIDATION',
#        'LIQUOR LAW VIOLATION', 'STALKING', 'PROSTITUTION', 'OBSCENITY',
#        'GAMBLING', 'OTHER NARCOTIC VIOLATION', 'PUBLIC INDECENCY',
#        'HUMAN TRAFFICKING', 'NON-CRIMINAL'], dtype=object)

# %%
data.groupby('Primary Type').size()
# Out:
# Primary Type
# ARSON                                  208
# ASSAULT                               9019
# BATTERY                              17729
# BURGLARY                              3053
# CONCEALED CARRY LICENSE VIOLATION       74
# CRIMINAL DAMAGE                      11959
# CRIMINAL SEXUAL ASSAULT                620
# CRIMINAL TRESPASS                     2004
# DECEPTIVE PRACTICE                    6618
# GAMBLING                                 3
# HOMICIDE                               249
# HUMAN TRAFFICKING                        4
# INTERFERENCE WITH PUBLIC OFFICER       250
# INTIMIDATION                           123
# KIDNAPPING                              51
# LIQUOR LAW VIOLATION                    82
# MOTOR VEHICLE THEFT                  12282
# NARCOTICS                             2079
# NON-CRIMINAL                             2
# OBSCENITY                               17
# OFFENSE INVOLVING CHILDREN             841
# ...

# %%
data.groupby(['Primary Type', 'Arrest']).size()
# Out:
# Primary Type                       Arrest
# ARSON                              False       192
#                                    True         16
# ASSAULT                            False      8138
#                                    True        881
# BATTERY                            False     15091
#                                    True       2638
# BURGLARY                           False      2932
#                                    True        121
# CONCEALED CARRY LICENSE VIOLATION  False         5
#                                    True         69
# CRIMINAL DAMAGE                    False     11584
#                                    True        375
# CRIMINAL SEXUAL ASSAULT            False       609
#                                    True         11
# CRIMINAL TRESPASS                  False      1414
#                                    True        590
# DECEPTIVE PRACTICE                 False      6307
#                                    True        311
# ...

# %%
data['Community Area'].unique()
# Out:
# array([25, 22, 32, 24, 28,  7, 43, 65, 45, 26, 23, 46, 68, 44, 27,  3, 77,
#        41, 67, 15,  8,  4, 75, 61, 69, 58, 29, 34, 76,  2, 73, 30, 16, 42,
#        64, 33, 20, 31, 63, 14, 18, 35, 39, 49, 71, 19, 53, 12, 40, 11, 70,
#        10, 62, 38,  6, 51, 37, 60, 48,  5,  9, 17, 66, 13, 56, 52, 36, 72,
#        54,  1, 74, 55, 21, 47, 57, 59, 50])

# %%
byarea = data.groupby('Community Area').size()

# %%
print(byarea)
# Out:
# Community Area
# 1     1781
# 2     1486
# 3     1760
# 4      851
# 5      593
#       ...
# 73    1414
# 74     247
# 75     841
# 76     744
# 77    1286
# Length: 77, dtype: int64

# %%
byarea.plot()
# Out:
# <AxesSubplot: xlabel='Community Area'>

# %%
data.describe()
# Out:
#                  ID           Beat       District           Ward  \
# count  1.041780e+05  104178.000000  104178.000000  104177.000000
# mean   1.298823e+07    1149.874052      11.269212      23.060685
# std    6.347724e+05     711.421430       7.110791      14.034500
# min    2.727900e+04     111.000000       1.000000       1.000000
# 25%    1.297947e+07     532.000000       5.000000       9.000000
# 50%    1.301940e+07    1031.000000      10.000000      23.000000
# 75%    1.305859e+07    1731.000000      17.000000      34.000000
# max    1.310330e+07    2535.000000      31.000000      50.000000
#
#        Community Area  X Coordinate  Y Coordinate      Year       Latitude  \
# count   104178.000000  1.036910e+05  1.036910e+05  104178.0  103691.000000
# mean        36.689378  1.165350e+06  1.886623e+06    2023.0      41.844473
# std         21.549157  1.648719e+04  3.180860e+04       0.0       0.087475
# min          1.000000  1.091242e+06  1.813897e+06    2023.0      41.644590
# ...
